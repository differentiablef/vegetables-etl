# %%
#Importing Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Reading CSV File
vitamins_df = pd.read_csv("C:\\Users\\MainUser1\\Desktop\\etl\\vitamins.csv")
vitamins_df.head()
# Out:
#         name  vitamin_a  thiamine_b1  riboflavin_b2  niacin_b3  vitamin_b6  \
# 0  Asparagus         71           14             14         98          97
# 1   Broccoli         14           71             12         64          18
# 2  Cucurbita         10           48             14         49          29
# 3    Spinach         93           78             19         72          20
#
#    vitamin_c  vitamin_k
# 0         56         41
# 1         90         10
# 2         12         30
# 3         28         20

# %%
# Set x axis and tick locations
x_axis = np.arange(len(vitamins_df))
tick_locations = [value for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(10,8))
plt.bar(x_axis, vitamins_df["vitamin_a"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, vitamins_df["name"], rotation="vertical")
plt.title("Vitamin A")
plt.xlabel("Vegetables")
plt.ylabel("Amount per 100gm")
# Out:
# Text(0, 0.5, 'Amount per 100gm')

# %%
#Thiamine Rich
plt.figure(figsize=(10,8))
plt.bar(x_axis, vitamins_df["thiamine_b1"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, vitamins_df["name"], rotation="vertical")
plt.title("Thiamine B1")
plt.xlabel("Vegetables")
plt.ylabel("Amount per 100gm (unit is mg)")
# Out:
# Text(0, 0.5, 'Amount per 100gm (unit is mg)')

# %%
#Riboflavin Rich
plt.figure(figsize=(10,8))
plt.bar(x_axis, vitamins_df["riboflavin_b2"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, vitamins_df["name"], rotation="vertical")
plt.title("Riboflavin B2")
plt.xlabel("Vegetables")
plt.ylabel("Amount per 100gm (unit is mg)")
# Out:
# Text(0, 0.5, 'Amount per 100gm (unit is mg)')

# %%
#Niacin B3 Rich
plt.figure(figsize=(10,8))
plt.bar(x_axis, vitamins_df["niacin_b3"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, vitamins_df["name"], rotation="vertical")
plt.title("Niacin B3")
plt.xlabel("Vegetables")
plt.ylabel("Amount per 100gm (unit is mg)")
# Out:
# Text(0, 0.5, 'Amount per 100gm (unit is mg)')

# %%
#Vitamin B6 Rich
plt.figure(figsize=(10,8))
plt.bar(x_axis, vitamins_df["vitamin_b6"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, vitamins_df["name"], rotation="vertical")
plt.title("Vitamin B6")
plt.xlabel("Vegetables")
plt.ylabel("Amount per 100gm (unit is mg)")
# Out:
# Text(0, 0.5, 'Amount per 100gm (unit is mg)')

# %%
#Vitamin C Rich
plt.figure(figsize=(10,8))
plt.bar(x_axis, vitamins_df["vitamin_c"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, vitamins_df["name"], rotation="vertical")
plt.title("Vitamin C")
plt.xlabel("Vegetables")
plt.ylabel("Amount per 100gm (unit is mg)")
# Out:
# Text(0, 0.5, 'Amount per 100gm (unit is mg)')

# %%
#Vitamin K Rich
plt.figure(figsize=(10,8))
plt.bar(x_axis, vitamins_df["vitamin_k"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, vitamins_df["name"], rotation="vertical")
plt.title("VItamin K")
plt.xlabel("Vegetables")
plt.ylabel("Amount per 100gm (unit is mg)")
# Out:
# Text(0, 0.5, 'Amount per 100gm (unit is mg)')
